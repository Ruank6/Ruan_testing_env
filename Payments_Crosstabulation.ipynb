# %%
import pandas as pd
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
df = pd.read_csv("/Users/ruank6/Desktop/Payments.csv")

# %%
df.describe()
# Out:
#        Accountnumber            DD           CPA            EP            PR  \
# count   6.051600e+04  60516.000000  60516.000000  60516.000000  60516.000000
# mean    2.617694e+09      0.498810      0.494051      0.505751      0.495935
# std     2.979657e+10      0.500003      0.499969      0.499971      0.499988
# min     4.248500e+04      0.000000      0.000000      0.000000      0.000000
# 25%     5.261682e+07      0.000000      0.000000      0.000000      0.000000
# 50%     9.911475e+07      0.000000      0.000000      1.000000      0.000000
# 75%     6.910123e+08      1.000000      1.000000      1.000000      1.000000
# max     1.060000e+12      1.000000      1.000000      1.000000      1.000000
#
#                  GS           DCP           DCA         OTHER
# count  60516.000000  60516.000000  60516.000000  60516.000000
# mean       0.511303      0.506445      0.510410      0.506147
# std        0.499876      0.499963      0.499896      0.499966
# ...

# %%
pd.crosstab([df.DD,df.CPA,df.EP,df.PR,df.GS,df.DCP,df.DCA],df.OTHER,margins=True)
# Out:
# OTHER                         0      1    All
# DD  CPA EP PR GS DCP DCA
# 0   0   0  0  0  0   0      216    324    540
#                      1      348    264    612
#                  1   0      240    270    510
#                      1      246    372    618
#               1  0   0      162    240    402
#                      1      294    228    522
#                  1   0      216    276    492
#                      1      210    336    546
#            1  0  0   0      264    240    504
#                      1      180    306    486
#                  1   0      186    150    336
#                      1      216    264    480
#               1  0   0      270    198    468
#                      1      174    294    468
#                  1   0      276    264    540
#                      1      216    180    396
#         1  0  0  0   0      258    294    552
#                      1      282    228    510
#                  1   0      216    120    336
# ...
